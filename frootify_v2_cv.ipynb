# %% [markdown]
# <a href="https://colab.research.google.com/github/Nightfury2062/frootify_v2_tomato_classifier/blob/main/frootify_v2_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.2 MB/s eta 0:00:00
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
from ultralytics import YOLO

# %%
import shutil
import os

drive_dataset = "/content/drive/MyDrive/Tomato Detection Fresh or Rotten.v10i.yolov8"
local_dataset = "/content/Tomato Detection Fresh or Rotten.v10i.yolov8"

# Remove old copy if it exists
if os.path.exists(local_dataset):
    shutil.rmtree(local_dataset)

print("Copying dataset to Colab SSD...")
shutil.copytree(drive_dataset, local_dataset)

print("Done!")
# Out:
# Copying dataset to Colab SSD...
# Done!

# %%
print(os.path.exists(local_dataset))
print(os.listdir(local_dataset))
# Out:
# True
# ['valid', 'data.yaml', 'test', 'README.dataset.txt', 'README.roboflow.txt', 'train']

# %%
yaml_content = """train: train/images
val: valid/images
test: test/images

nc: 2
names:
  0: Fresh Tomato
  1: Rotten Tomato
"""

with open(local_dataset + "/data.yaml", "w") as f:
    f.write(yaml_content)

print("data.yaml updated")
# Out:
# data.yaml updated

# %%
with open(local_dataset + "/data.yaml") as f:
    print(f.read())
# Out:
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 2
# names:
#   0: Fresh Tomato
#   1: Rotten Tomato

# %%
model = YOLO("yolov8n.pt")

# %%
# results = model.train(
#     data=local_dataset + "/data.yaml",
#     epochs=50,
#     imgsz=640,
#     batch=16,
#     workers=2,
#     device=0,
#     pretrained=True,
#     optimizer="auto",
#     patience=10,
#     project="/content/drive/MyDrive/frootify_v2_training",
#     name="tomato_detector"
# )
# Out:
# Ultralytics 8.4.64 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO("/content/drive/MyDrive/frootify_v2_training/tomato_detector/weights/best.pt")

model.export(
    format="onnx",
    imgsz=640,
    simplify=True,
    opset=12
)
# Out:
# Ultralytics 8.4.64 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/frootify_v2_training/tomato_detector/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 387ms
# Prepared 4 packages in 1.87s
# Installed 4 packages in 364ms
#  + colorama==0.4.6
#  + onnx==1.21.0
#  + onnxruntime==1.26.0
#  + onnxslim==0.1.94
#
# requirements: AutoUpdate success ✅ 3.3s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...

# %%
print(os.path.exists("/content/drive/MyDrive/frootify_v2_training/tomato_detector/weights/best.onnx"))
# Out:
# True

# %%
print(model.names)
# Out:
# {0: 'Fresh Tomato', 1: 'Rotten Tomato'}
